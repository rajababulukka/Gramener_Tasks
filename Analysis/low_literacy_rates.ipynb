# %%
import numpy as np                # to load numpy library
import pandas as pd               # to load panda library
import matplotlib.pyplot as plt   # to load the matplotlib library only pyplot to ploy the graphs
# %matplotlib inline                
# %pylab inline

csv_data = "india-districts-census-2011.csv"
data_frame = pd.read_csv(csv_data)     # reading file and storing data to data_frame
data_frame_selected_colomns = data_frame[["State name","Literate","Population"]] # selecting required colom names from data_frame
data_frame_selected_colomns            # checking wheather data getting in proper way or not for data frame selected coloms
# Out:
# Populating the interactive namespace from numpy and matplotlib
#                     State name  Literate  Population
# 0              JAMMU & KASHMIR    439654      870354
# 1              JAMMU & KASHMIR    335649      753745
# 2              JAMMU & KASHMIR     93770      133487
# 3              JAMMU & KASHMIR     86236      140802
# 4              JAMMU & KASHMIR    261724      476835
# 5              JAMMU & KASHMIR    364109      642415
# 6              JAMMU & KASHMIR    389204      616435
# 7              JAMMU & KASHMIR    545149     1008039
# 8              JAMMU & KASHMIR    185979      392232
# 9              JAMMU & KASHMIR    748584     1236829
# 10             JAMMU & KASHMIR    143276      297446
# 11             JAMMU & KASHMIR    293958      560440
# 12             JAMMU & KASHMIR    136500      266215
# 13             JAMMU & KASHMIR    545532     1078692
# 14             JAMMU & KASHMIR    209085      424483
# 15             JAMMU & KASHMIR    219083      409936
# 16             JAMMU & KASHMIR    124065      283713
# 17             JAMMU & KASHMIR    107506      230696
# 18             JAMMU & KASHMIR    322354      554985
# 19             JAMMU & KASHMIR    150542      314667
# 20             JAMMU & KASHMIR   1137135     1529958
# 21             JAMMU & KASHMIR    228139      318898
# 22            HIMACHAL PRADESH    323842      519080
# 23            HIMACHAL PRADESH   1152640     1510075
# 24            HIMACHAL PRADESH     21845       31564
# 25            HIMACHAL PRADESH    307672      437903
# 26            HIMACHAL PRADESH    723747      999777
# 27            HIMACHAL PRADESH    358091      454768
# 28            HIMACHAL PRADESH    399715      521173
# 29            HIMACHAL PRADESH    287620      381956
# ..                         ...       ...         ...
# 610                 TAMIL NADU    569647      735394
# 611                 TAMIL NADU   1481834     2159775
# 612                 TAMIL NADU    727044     1064493
# 613                 TAMIL NADU   2038981     2722290
# 614                 TAMIL NADU    375823      565223
# 615                 TAMIL NADU    480604      754894
# 616                 TAMIL NADU   1815281     2605914
# 617                 TAMIL NADU   1213008     1616450
# 618                 TAMIL NADU    946471     1264277
# 619                 TAMIL NADU   1790998     2405890
# 620                 TAMIL NADU   1110545     1618345
# 621                 TAMIL NADU    959744     1339101
# 622                 TAMIL NADU   2273430     3038252
# 623                 TAMIL NADU    870080     1245899
# 624                 TAMIL NADU   1398788     1942288
# 625                 TAMIL NADU    978946     1353445
# 626                 TAMIL NADU   1349697     1750176
# 627                 TAMIL NADU   2273457     3077233
# 628                 TAMIL NADU   1548738     1870374
# 629                 TAMIL NADU    917709     1506843
# 630                 TAMIL NADU   1187958     1879809
# 631                 TAMIL NADU   2635907     3458045
# 632                 TAMIL NADU   1760566     2479052
# 633                 PUDUCHERRY     39274       55626
# 634                 PUDUCHERRY    726649      950289
# 635                 PUDUCHERRY     36470       41816
# 636                 PUDUCHERRY    154916      200222
# 637  ANDAMAN & NICOBAR ISLANDS     25332       36842
# 638  ANDAMAN & NICOBAR ISLANDS     78683      105597
# 639  ANDAMAN & NICOBAR ISLANDS    190266      238142
#
# [640 rows x 3 columns]

# %%
sum_coloms_by_state_name = data_frame_selected_colomns.groupby('State name').sum()    # sum all the coloms data based on group of states
literacy_rate =  sum_coloms_by_state_name["Literate"]/sum_coloms_by_state_name["Population"]*100     # calculating literacy for statewise
literacy_rate                                                                          # checking wheather data getting in proper way or not for literacy rate
# Out:
# State name
# ANDAMAN & NICOBAR ISLANDS    77.324144
# ANDHRA PRADESH               59.773345
# ARUNACHAL PRADESH            55.358102
# ASSAM                        61.456892
# BIHAR                        50.436916
# CHANDIGARH                   76.312284
# CHHATTISGARH                 60.206705
# DADRA & NAGAR HAVELI         64.947383
# DAMAN & DIU                  77.454604
# GOA                          79.907511
# GUJARAT                      67.990681
# HARYANA                      65.475466
# HIMACHAL PRADESH             73.416288
# JAMMU & KASHMIR              56.351669
# JHARKHAND                    55.559581
# KARNATAKA                    66.531016
# KERALA                       84.223710
# LAKSHADWEEP                  81.511641
# MADHYA PRADESH               59.001861
# MAHARASHTRA                  72.573770
# MANIPUR                      66.828210
# MEGHALAYA                    60.164199
# MIZORAM                      77.303168
# NAGALAND                     67.851031
# NCT OF DELHI                 75.874504
# ODISHA                       63.711955
# PUDUCHERRY                   76.710341
# PUNJAB                       67.429294
# RAJASTHAN                    55.836841
# SIKKIM                       72.874019
# TAMIL NADU                   71.849814
# TRIPURA                      76.343124
# UTTAR PRADESH                57.252497
# UTTARAKHAND                  68.220839
# WEST BENGAL                  67.419917
# dtype: float64

# %%
literacy_rate.sort_values(inplace = True) # soring values in assending order
literacy_rate.plot(kind='bar')            # geographic map is not possible so taken bar chart to display data 
plt.show()                                # showing chart with
